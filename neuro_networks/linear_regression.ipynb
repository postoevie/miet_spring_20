# %%
import tensorflow.compat.v1 as tf
print(tf)
import numpy
import matplotlib.pyplot as plt
rng = numpy.random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-c37713276d49> in <module>
# ----> 1 import tensorflow.compat.v1 as tf
#       2 print(tf)
#       3 import numpy
#       4 import matplotlib.pyplot as plt
#       5 rng = numpy.random
#
# ModuleNotFoundError: No module named 'tensorflow.compat.v1'

# %%
# Обучающие данные
train_X = numpy.asarray([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,
                         7.042,10.791,5.313,7.997,5.654,9.27,3.1])
train_Y = numpy.asarray([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
                         2.827,3.465,1.65,2.904,2.42,2.94,1.3])
n_samples = train_X.shape[0]

# %% [markdown]
# **ВАШ КОД ЗДЕСЬ:**

# %%
plt.plot(train_X, train_Y, 'ro', label='Originaldata')
plt.legend()
plt.show()

# %%
# Параметры обучения
learning_rate = 0.01
training_epochs = 1500
display_step = 50

# %%
# tf Graph Input
X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
W = tf.Variable(rng.randn(), name="weight")
b = tf.Variable(rng.randn(), name="bias")

# %%
# Construct a linear model
pred = tf.add(tf.multiply(X, W), b)

# %%
# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
# Using InteractiveSession (more convenient while using Notebooks)
sess = tf.InteractiveSession()
sess.run(init)

# Fit all training data
for epoch in range(training_epochs):
  for (x, y) in zip(train_X, train_Y):
    sess.run(optimizer, feed_dict={X: x, Y: y})

  #Display logs per epoch step
  if (epoch+1) % display_step == 0:
    c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
    print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "W=", sess.run(W), "b=", sess.run(b))

print("Optimization Finished!")
training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
print("Training cost=", training_cost, "W=", sess.run(W), "b=", sess.run(b), '\n')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
# Epoch: 0050 cost= 0.092047200 W= 0.18130057 b= 1.2927614
# Epoch: 0100 cost= 0.090315133 W= 0.18536246 b= 1.2635406
# Epoch: 0150 cost= 0.088782586 W= 0.18918286 b= 1.2360566
# Epoch: 0200 cost= 0.087426655 W= 0.19277598 b= 1.2102087
# Epoch: 0250 cost= 0.086227037 W= 0.1961549 b= 1.1859002
# Epoch: 0300 cost= 0.085165657 W= 0.19933285 b= 1.1630387
# Epoch: 0350 cost= 0.084226429 W= 0.20232186 b= 1.1415361
# Epoch: 0400 cost= 0.083395340 W= 0.2051332 b= 1.1213117
# Epoch: 0450 cost= 0.082659915 W= 0.20777726 b= 1.1022902
# Epoch: 0500 cost= 0.082009152 W= 0.21026419 b= 1.0843993
# Epoch: 0550 cost= 0.081433289 W= 0.21260317 b= 1.0675731
# Epoch: 0600 cost= 0.080923714 W= 0.21480292 b= 1.0517479
# Epoch: 0650 cost= 0.080472663 W= 0.2168722 b= 1.0368618
# Epoch: 0700 cost= 0.080073543 W= 0.21881835 b= 1.0228611
# Epoch: 0750 cost= 0.079720318 W= 0.22064868 b= 1.0096941
# Epoch: 0800 cost= 0.079407670 W= 0.22237037 b= 0.9973083
# Epoch: 0850 cost= 0.079130985 W= 0.22398958 b= 0.98565984
# Epoch: 0900 cost= 0.078886114 W= 0.22551253 b= 0.97470367
# Epoch: 0950 cost= 0.078669354 W= 0.22694494 b= 0.96439934
# Epoch: 1000 cost= 0.078477480 W= 0.22829206 b= 0.95470816
# Epoch: 1050 cost= 0.078307703 W= 0.22955877 b= 0.9455956
# Epoch: 1100 cost= 0.078157388 W= 0.23075022 b= 0.93702424
# Epoch: 1150 cost= 0.078024343 W= 0.23187082 b= 0.9289629
# Epoch: 1200 cost= 0.077906549 W= 0.23292471 b= 0.92138135
# Epoch: 1250 cost= 0.077802263 W= 0.233916 b= 0.9142499
# Epoch: 1300 cost= 0.077709921 W= 0.23484826 b= 0.9075431
# Epoch: 1350 cost= 0.077628180 W= 0.23572524 b= 0.9012343
# Epoch: 1400 cost= 0.077555731 W= 0.23655005 b= 0.8953009
# Epoch: 1450 cost= 0.077491626 W= 0.23732574 b= 0.88972044
# Epoch: 1500 cost= 0.077434860 W= 0.23805532 b= 0.8844721
# Optimization Finished!
# Training cost= 0.07743486 W= 0.23805532 b= 0.8844721

# %% [markdown]
# **ВАШ КОД ЗДЕСЬ:**

# %%
plt.plot(train_X, train_Y, 'ro', label='Originaldata')
plt.plot(train_X, sess.run(W) * train_X + sess.run(b), label='Originaldata')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-923439eeaba2> in <module>
#       1 plt.plot(train_X, train_Y, 'ro', label='Originaldata')
# ----> 2 plt.plot(train_X, sess.run(W) * train_X + sess.run(b), label='Originaldata')
#       3 plt.legend()
#       4 plt.show()
#
# NameError: name 'sess' is not defined
